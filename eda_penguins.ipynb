# %% [markdown]
# <a href="https://colab.research.google.com/github/alexjochs/ECE_539_Penguins/blob/aochs%2Fdownload_data/eda_penguins.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Pillow

# %%
from google.colab import drive
drive.mount('/content/gdrive')

data_filepath = r"/content/gdrive/MyDrive/'Penguin counting'/data_peng_watch"
# Out:
# Mounted at /content/gdrive

# %%
tar_files_list = !ls -1 /content/gdrive/MyDrive/'Penguin counting'/data_peng_watch

for tar_file in tar_files_list[1:]:
  tar_file_path = data_filepath + '/' + tar_file
  # !tar --gunzip --extract --verbose --file={tar_file_path} --directory /content/penguins

# %%
import matplotlib.pyplot as plt
import PIL

# %%
# load and show an image with Pillow
from PIL import Image
# load the image
image = Image.open('/content/penguins/DAMOa/DAMOa2014a_000001.JPG')
# summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)
# show the image
image.show()
# Out:
# JPEG
# RGB
# (2048, 1536)

# %%
# load and display an image with Matplotlib
from matplotlib import image
from matplotlib import pyplot as plt
# load image as pixel array
data = image.imread('/content/penguins/DAMOa/DAMOa2014a_000001.JPG')
# summarize shape of the pixel array
print(data.dtype)
print(data.shape)
# display the array of pixels as an image
fig = plt.figure(figsize=(10, 10))
plt.imshow(data)
# Out:
# uint8
# (1536, 2048, 3)
